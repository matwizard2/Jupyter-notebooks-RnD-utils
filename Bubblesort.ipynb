# %%
import timeit
import random

# %%
del l

# %%
m=[1,4,2,4,1,6,3,5]
l = m[:]
m.sort()
print(l)
#print(m)
#l[0],l[1]=l[1],l[0]
print(l)
# Out:
# [1, 4, 2, 4, 1, 6, 3, 5]
# [1, 4, 2, 4, 1, 6, 3, 5]

# %%
def bubblesort(l):
    q=l[:]
    n=len(q)
    for j in range(n-1):
        for i in range(n-1):
            if q[i]>q[i+1]:
                q[i],q[i+1] = q[i+1],q[i]
    return(q)

# %%
q=[2,9,1]
print(l)
print(bubblesort(l))
print(l)
print(q)
# Out:
# [1, 4, 2, 4, 1, 6, 3, 5]
# [1, 1, 2, 3, 4, 4, 5, 6]
# [1, 4, 2, 4, 1, 6, 3, 5]
# [2, 9, 1]

# %%
l=[]
for i in range(10000):
    l+= [random.random()]

# %%
def bubblesortl():
    bubblesort(l)

# %%
timeit.timeit(bubblesortl,number=1)
# Out:
# 117.94432770900039
